# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Product': ['Laptop', 'Mobile', 'Laptop', 'Tablet', 'Mobile', 'Laptop'],
    'Sales': [120, 200, 150, 80, 250, 180],
    'Revenue': [120000, 100000, 150000, 40000, 125000, 180000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Month Product  Sales  Revenue
# 0   Jan  Laptop    120   120000
# 1   Feb  Mobile    200   100000
# 2   Mar  Laptop    150   150000
# 3   Apr  Tablet     80    40000
# 4   May  Mobile    250   125000
# 5   Jun  Laptop    180   180000

# %%
print("Total Sales:", df['Sales'].sum())
print("Total Revenue:", df['Revenue'].sum())
print("Best Selling Product:", df.groupby('Product')['Sales'].sum().idxmax())
print("Highest Revenue Month:", df.loc[df['Revenue'].idxmax(), 'Month'])
# Out:
# Total Sales: 980
# Total Revenue: 715000
# Best Selling Product: Laptop
# Highest Revenue Month: Jun

# %%
product_sales = df.groupby('Product')['Sales'].sum()

product_sales.plot(kind='bar', color='orange')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()

# %%
df.plot(x='Month', y='Revenue', kind='line', color='green', marker='o')
plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.tight_layout()
plt.show()
